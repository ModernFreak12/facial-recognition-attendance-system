# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import torch
import os

# %%
torch.__version__

# %%
ROOT_DIR = os.path.dirname(os.getcwd())

# %%
model = YOLO(f"{ROOT_DIR}/models/face_detection_new/runs/face_yolo11s/weights/best.pt")

# %%
image_path = "test2.png"

# %%
results = model.predict(
    source=image_path,
    save=False,
    conf=0.7,
    imgsz=1280,
    show_conf=True
)
# Out:
# image 1/1 d:\1. Aayush\Projects\facial-recognition-attendance-system\notebooks\test2.png: 736x1280 15 faces, 452.7ms
# Speed: 9.1ms preprocess, 452.7ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 1280)

# %%
annotated_frame = results[0].plot()

# %%
annotated_frame = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(8, 8))
plt.imshow(annotated_frame)
plt.axis("off")
plt.show()
